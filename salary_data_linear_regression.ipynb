# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/My Drive/MLdataset/
# Out:
# /content/gdrive/My Drive/MLdataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
dataset= pd.read_csv('Salary_Data.csv')
X= dataset.iloc[:,:-1].values
Y= dataset.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test= train_test_split(X,Y,test_size= 1/3)
from sklearn.linear_model import LinearRegression
regressor= LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X_train, Y_train, color='green')
plt.plot(X_train, regressor.predict(X_train), color='blue')
plt.title('Experience vs Salary (Training set)')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()
plt.scatter(X_test, Y_test, color='green')
plt.plot(X_test, regressor.predict(X_test), color='blue')
plt.title('Experience vs Salary (Training set)')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()

# %%
k = float(input("What is your years of experience -> "))
salary = float((regressor.predict([[k]])*12)/100000)
fnum = "{:.2f}".format(salary)
print('The Salary you deserve is ->',fnum , "Lakhs per annum")
# Out:
# What is your years of experience -> 65.3
# The Salary you deserve is -> 75.75 Lakhs per annum
